# %%
import audio as A
import files as IO
import plotly.express as px
import numpy as np
import pandas as pd
import viz as V

# %%
files  = IO.get_files('../data/input/')

# %%
data = []
start = 9
end = start + 1
# for f in files[start:end]:
for i, f in enumerate(files):
    d = A.AudioData(f, 0, 0)
    d.set_spectrum()
    d.analyze()
    d.set_harmonics()
    d.resynthesize_cycle()
    data.append(d)
# Out:
# Error setting compression of 1F_shaker, using default

# %%
V.generate_master_plot(data)

# %%
px.line(d.analysis)
